# %% [markdown]
# # Export Data
# ## NYC Open *Big* Data
# Author: Mark Bauer

# %%
import pandas as pd
import time
from datetime import datetime
import requests

# %%
path = 'https://data.cityofnewyork.us/api/views/'
views_df = pd.read_json(path)

print(views_df.shape)
views_df.head()
# Out:
# (3237, 50)
#           id                                               name assetType  \
# 0  fkec-mjr6  DOHMH Cryptosporidiosis by Race/Ethnicity, Age...   dataset
# 1  r6e8-2fwe  Location of Disposal Facilities and Sites Used...       map
# 2  9e2b-mctv                  New York City Bike Routes\t (Map)       map
# 3  mzxg-pwib                          New York City Bike Routes   dataset
# 4  6r9j-qrwz              DSNY Disposal Facilities Used by Year   dataset
#
#    averageRating         category   createdAt  \
# 0              0           Health  1722867167
# 1              0  City Government  1722436736
# 2              0              NaN  1721837332
# 3              0              NaN  1721836651
# 4              0  City Government  1720809444
#
#                                          description  \
# 0  Cryptosporidiosis, number of cases and annual ...
# 1  The location of the disposal facilities where ...
# 2  The New York City Department of Transportation...
# 3  The New York City Department of Transportation...
# 4  A listing of the facilities used by year to ha...
#
#                 displayType  downloadCount  hideFromCatalog  ...  \
# 0                     table              1            False  ...
# 1  visualization_canvas_map              0            False  ...
# 2  visualization_canvas_map              0            False  ...
# 3                     table             34            False  ...
# 4                     table              6            False  ...
#
#    blobFilename  blobFileSize  blobId  blobMimeType  ratings childViews  \
# 0           NaN           NaN     NaN           NaN      NaN        NaN
# 1           NaN           NaN     NaN           NaN      NaN        NaN
# 2           NaN           NaN     NaN           NaN      NaN        NaN
# 3           NaN           NaN     NaN           NaN      NaN        NaN
# 4           NaN           NaN     NaN           NaN      NaN        NaN
#
#    indexUpdatedAt  iconUrl  previewImageId disabledFeatureFlags
# 0             NaN      NaN             NaN                  NaN
# 1             NaN      NaN             NaN                  NaN
# 2             NaN      NaN             NaN                  NaN
# 3             NaN      NaN             NaN                  NaN
# 4             NaN      NaN             NaN                  NaN
#
# [5 rows x 50 columns]

# %%
views_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3237 entries, 0 to 3236
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        3237 non-null   object
#  1   name                      3237 non-null   object
#  2   assetType                 3237 non-null   object
#  3   averageRating             3237 non-null   int64
#  4   category                  3127 non-null   object
#  5   createdAt                 3237 non-null   int64
#  6   description               3163 non-null   object
#  7   displayType               3237 non-null   object
#  8   downloadCount             3237 non-null   int64
#  9   hideFromCatalog           3237 non-null   bool
#  10  hideFromDataJson          3237 non-null   bool
#  11  locked                    3237 non-null   bool
#  12  newBackend                3237 non-null   bool
#  13  numberOfComments          3237 non-null   int64
#  14  oid                       3237 non-null   int64
#  15  provenance                3237 non-null   object
#  16  publicationAppendEnabled  3237 non-null   bool
#  17  publicationDate           3212 non-null   float64
#  18  publicationGroup          3237 non-null   int64
#  19  publicationStage          3237 non-null   object
#  20  rowsUpdatedAt             3064 non-null   float64
#  21  rowsUpdatedBy             2797 non-null   object
#  22  tableId                   3237 non-null   int64
#  23  totalTimesRated           3237 non-null   int64
#  24  viewCount                 3237 non-null   int64
#  25  viewLastModified          3237 non-null   int64
#  26  viewType                  3237 non-null   object
#  27  approvals                 3237 non-null   object
#  28  clientContext             3237 non-null   object
#  29  grants                    3237 non-null   object
#  30  metadata                  3237 non-null   object
#  31  owner                     3237 non-null   object
#  32  rights                    3237 non-null   object
#  33  tableAuthor               3237 non-null   object
#  34  tags                      2441 non-null   object
#  35  flags                     3237 non-null   object
#  36  modifyingViewUid          201 non-null    object
#  37  rowClass                  1739 non-null   object
#  38  rowIdentifierColumnId     55 non-null     float64
#  39  locale                    398 non-null    object
#  40  blobFilename              275 non-null    object
#  41  blobFileSize              275 non-null    float64
#  42  blobId                    275 non-null    object
#  43  blobMimeType              275 non-null    object
#  44  ratings                   25 non-null     object
#  45  childViews                105 non-null    object
#  46  indexUpdatedAt            1864 non-null   float64
#  47  iconUrl                   41 non-null     object
#  48  previewImageId            112 non-null    object
#  49  disabledFeatureFlags      16 non-null     object
# dtypes: bool(5), float64(5), int64(10), object(30)
# memory usage: 1.1+ MB

# %%
views_df['displayType'].value_counts()
# Out:
# table                         2578
# visualization_canvas_map       213
# blob                           170
# href                           147
# map                            124
# story                            3
# visualization_canvas_table       1
# visualization_canvas_chart       1
# Name: displayType, dtype: int64

# %%
views_df['assetType'].value_counts()
# Out:
# dataset          2554
# map               337
# file              170
# href              147
# filter             24
# story               3
# visualization       1
# chart               1
# Name: assetType, dtype: int64

# %%
condition = (
    (views_df['displayType'] == 'table')
    & (views_df['assetType'] == 'dataset')
)
    
views_df = views_df.loc[condition].reset_index(drop=True)

print(views_df.shape)
views_df.head()
# Out:
# (2554, 50)
#           id                                               name assetType  \
# 0  fkec-mjr6  DOHMH Cryptosporidiosis by Race/Ethnicity, Age...   dataset
# 1  mzxg-pwib                          New York City Bike Routes   dataset
# 2  6r9j-qrwz              DSNY Disposal Facilities Used by Year   dataset
# 3  99xv-he3n     DSNY Disposal Sites Used by Facilities by Year   dataset
# 4  ufxk-pq9j  Location of Disposal Facilities and Sites Used...   dataset
#
#    averageRating         category   createdAt  \
# 0              0           Health  1722867167
# 1              0              NaN  1721836651
# 2              0  City Government  1720809444
# 3              0  City Government  1720808339
# 4              0  City Government  1720806845
#
#                                          description displayType  \
# 0  Cryptosporidiosis, number of cases and annual ...       table
# 1  The New York City Department of Transportation...       table
# 2  A listing of the facilities used by year to ha...       table
# 3  A listing of the disposal sites used by each f...       table
# 4  The location of the disposal facilities where ...       table
#
#    downloadCount  hideFromCatalog  ...  blobFilename  blobFileSize  blobId  \
# 0              1            False  ...           NaN           NaN     NaN
# 1             34            False  ...           NaN           NaN     NaN
# 2              6            False  ...           NaN           NaN     NaN
# 3              7            False  ...           NaN           NaN     NaN
# 4             16            False  ...           NaN           NaN     NaN
#
#    blobMimeType  ratings childViews  indexUpdatedAt  iconUrl  previewImageId  \
# 0           NaN      NaN        NaN             NaN      NaN             NaN
# 1           NaN      NaN        NaN             NaN      NaN             NaN
# 2           NaN      NaN        NaN             NaN      NaN             NaN
# 3           NaN      NaN        NaN             NaN      NaN             NaN
# 4           NaN      NaN        NaN             NaN      NaN             NaN
#
#   disabledFeatureFlags
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 50 columns]

# %%
views_df.groupby(by=['assetType', 'displayType'])['id'].count()
# Out:
# assetType  displayType
# dataset    table          2554
# Name: id, dtype: int64

# %%
# Initialize variables
API_BASE = 'https://data.cityofnewyork.us/resource/'
DATASETS = views_df['id'].to_list()
EXPORT_LOG = 'log.txt'
REQUEST_INTERVAL = 5  # seconds between requests

# Function to log messages
def log_message(message: str) -> None:
    """Log messages with timestamp."""
    with open(EXPORT_LOG, 'a') as file:
        file.write(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')},{dataset},{message}\n")

for dataset in DATASETS:
    try:
        # Attempt to read the dataset
        response = requests.get(f'{API_BASE}{dataset}.json?$select=count(*)')
        response.raise_for_status()  # Ensure we catch HTTP errors
        df = pd.read_json(response.text)
        count = df.values[0][0]
        log_message(f",{count}")

    except requests.RequestException as req_err:
        # Log request-related errors
        log_message(f"Request error for {dataset}: {req_err},")

    except ValueError as val_err:
        # Log JSON decoding errors
        log_message(f"Value error for {dataset}: {val_err},")

    except Exception as e:
        # Log any other unexpected errors
        log_message(f"Unexpected error for {dataset}: {e},")

    # Sleep to avoid hitting rate limits
    time.sleep(REQUEST_INTERVAL)
